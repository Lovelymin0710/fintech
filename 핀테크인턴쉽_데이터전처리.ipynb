# %%
import pandas as pd

# %% [markdown]
# ## 파일 다운로드

# %%
# 고객정보
A_ID=pd.read_csv('C:/Users/dlsrn/Desktop/핀테크 인턴쉽/데이터 전처리_1/SDBSAMPLE_A_ID.csv')

# 대출 (금융)
P_LN=pd.read_csv('C:/Users/dlsrn/Desktop/핀테크 인턴쉽/데이터 전처리_1/SDBSAMPLE_P_LN.csv')
# 대출 (대부)
P_LN_SP=pd.read_csv('C:/Users/dlsrn/Desktop/핀테크 인턴쉽/데이터 전처리_1/SDBSAMPLE_P_LN_SP.csv')

# 카드
P_CD_OPN=pd.read_csv('C:/Users/dlsrn/Desktop/핀테크 인턴쉽/데이터 전처리_1/SDBSAMPLE_P_CD_OPN.csv')
P_CD_USG=pd.read_csv('C:/Users/dlsrn/Desktop/핀테크 인턴쉽/데이터 전처리_1/SDBSAMPLE_P_CD_USG.csv')

# 보험
CT_RLPS=pd.read_csv('C:/Users/dlsrn/Desktop/핀테크 인턴쉽/데이터 전처리_1/SDBSAMPLE_I_CT_RLPS.csv')
CT_CONT_PVT=pd.read_csv('C:/Users/dlsrn/Desktop/핀테크 인턴쉽/데이터 전처리_1/SDBSAMPLE_I_CT_CONT_PVT.csv')

# %% [markdown]
# # 데이터 연동

# %% [markdown]
# - 대출(금융)<p>
# => A_ID + P_LN

# %%
A_ID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5051 entries, 0 to 5050
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   JOIN_SN      5051 non-null   int64
#  1   JOIN_SN_TYP  5051 non-null   int64
#  2   BTH_YR       5051 non-null   int64
#  3   GENDER       5051 non-null   int64
#  4   IS_KRN       5051 non-null   int64
# dtypes: int64(5)
# memory usage: 197.4 KB

# %%
 P_LN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75337 entries, 0 to 75336
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   YM           75337 non-null  int64
#  1   JOIN_SN      75337 non-null  int64
#  2   JOIN_SN_TYP  75337 non-null  int64
#  3   SCTR_CD      75337 non-null  int64
#  4   COM_SN       75337 non-null  int64
#  5   IS_ME        75337 non-null  int64
#  6   LN_CD_1      75337 non-null  int64
#  7   LN_CD_2      75337 non-null  int64
#  8   LN_CD_3      75337 non-null  int64
#  9   LN_DT        75337 non-null  int64
#  10  LN_AMT       75337 non-null  int64
#  11  RATE_YN      75337 non-null  int64
#  12  RPY_CD       75337 non-null  int64
#  13  EXP_DT       75337 non-null  int64
#  14  RATE         75337 non-null  int64
#  15  RPY_AMT      75337 non-null  int64
# dtypes: int64(16)
# memory usage: 9.2 MB

# %%
P_LN_cat = pd.merge(A_ID,P_LN,left_on = ['JOIN_SN','JOIN_SN_TYP'],right_on=['JOIN_SN','JOIN_SN_TYP'],how='inner')
P_LN_cat
# Out:
#        JOIN_SN  JOIN_SN_TYP  BTH_YR  GENDER  IS_KRN      YM  SCTR_CD   COM_SN  \
# 0       166677            1    1971       1       1  202003       21  1203668
# 1       166677            1    1971       1       1  201910       21  1203668
# 2       166677            1    1971       1       1  201912       21  1203668
# 3       166677            1    1971       1       1  202004       21  1203668
# 4       166677            1    1971       1       1  202005       21  1203668
# ...        ...          ...     ...     ...     ...     ...      ...      ...
# 75332   642762            1    1986       2       1  201910        1  7131311
# 75333    47028            1    1975       2       1  201810        5  8185966
# 75334    47028            1    1975       2       1  201811        5  8185966
# 75335    47028            1    1975       2       1  201909        5  8185966
# 75336    47028            1    1975       2       1  201806        5  8185966
#
# ...

# %%
P_LN_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75337 entries, 0 to 75336
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   JOIN_SN      75337 non-null  int64
#  1   JOIN_SN_TYP  75337 non-null  int64
#  2   BTH_YR       75337 non-null  int64
#  3   GENDER       75337 non-null  int64
#  4   IS_KRN       75337 non-null  int64
#  5   YM           75337 non-null  int64
#  6   SCTR_CD      75337 non-null  int64
#  7   COM_SN       75337 non-null  int64
#  8   IS_ME        75337 non-null  int64
#  9   LN_CD_1      75337 non-null  int64
#  10  LN_CD_2      75337 non-null  int64
#  11  LN_CD_3      75337 non-null  int64
#  12  LN_DT        75337 non-null  int64
#  13  LN_AMT       75337 non-null  int64
#  14  RATE_YN      75337 non-null  int64
#  15  RPY_CD       75337 non-null  int64
#  16  EXP_DT       75337 non-null  int64
#  17  RATE         75337 non-null  int64
#  18  RPY_AMT      75337 non-null  int64
# ...

# %% [markdown]
# - 대출(대부)<p>
# => A_ID + P_LN_SP

# %%
A_ID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5051 entries, 0 to 5050
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   JOIN_SN      5051 non-null   int64
#  1   JOIN_SN_TYP  5051 non-null   int64
#  2   BTH_YR       5051 non-null   int64
#  3   GENDER       5051 non-null   int64
#  4   IS_KRN       5051 non-null   int64
# dtypes: int64(5)
# memory usage: 197.4 KB

# %%
P_LN_SP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1717 entries, 0 to 1716
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   YM           1717 non-null   int64
#  1   JOIN_SN      1717 non-null   int64
#  2   JOIN_SN_TYP  1717 non-null   int64
#  3   SCTR_CD      1717 non-null   int64
#  4   COM_SN       1717 non-null   int64
#  5   IS_ME        1717 non-null   int64
#  6   LN_CD_1      1717 non-null   int64
#  7   LN_CD_2      1717 non-null   int64
#  8   LN_CD_3      1717 non-null   int64
#  9   LN_DT        1717 non-null   int64
#  10  LN_AMT       1717 non-null   int64
#  11  RATE_YN      1717 non-null   int64
#  12  RPY_CD       1717 non-null   int64
#  13  EXP_DT       1717 non-null   int64
#  14  RATE         1717 non-null   int64
#  15  RPY_AMT      1717 non-null   int64
# dtypes: int64(16)
# memory usage: 214.8 KB

# %%
P_LN_SP_cat=pd.merge(A_ID, P_LN_SP,left_on = ['JOIN_SN','JOIN_SN_TYP'],right_on=['JOIN_SN','JOIN_SN_TYP'],how='inner')
P_LN_SP_cat
# Out:
#       JOIN_SN  JOIN_SN_TYP  BTH_YR  GENDER  IS_KRN      YM  SCTR_CD   COM_SN  \
# 0     1650210            1    1964       1       1  201902       24  6749565
# 1     1650210            1    1964       1       1  201903       24  6749565
# 2     1650210            1    1964       1       1  201810       24  6749565
# 3     1650210            1    1964       1       1  201911       24  6749565
# 4     1650210            1    1964       1       1  202002       24  6749565
# ...       ...          ...     ...     ...     ...     ...      ...      ...
# 1712  1445086            1    1988       1       1  201910       24  2037199
# 1713  1445086            1    1988       1       1  201909       24  2037199
# 1714  1445086            1    1988       1       1  201908       24  2037199
# 1715  1445086            1    1988       1       1  201902       24  2037199
# 1716  1445086            1    1988       1       1  201811       24  9741399
#
# ...

# %%
P_LN_SP_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1717 entries, 0 to 1716
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   JOIN_SN      1717 non-null   int64
#  1   JOIN_SN_TYP  1717 non-null   int64
#  2   BTH_YR       1717 non-null   int64
#  3   GENDER       1717 non-null   int64
#  4   IS_KRN       1717 non-null   int64
#  5   YM           1717 non-null   int64
#  6   SCTR_CD      1717 non-null   int64
#  7   COM_SN       1717 non-null   int64
#  8   IS_ME        1717 non-null   int64
#  9   LN_CD_1      1717 non-null   int64
#  10  LN_CD_2      1717 non-null   int64
#  11  LN_CD_3      1717 non-null   int64
#  12  LN_DT        1717 non-null   int64
#  13  LN_AMT       1717 non-null   int64
#  14  RATE_YN      1717 non-null   int64
#  15  RPY_CD       1717 non-null   int64
#  16  EXP_DT       1717 non-null   int64
#  17  RATE         1717 non-null   int64
#  18  RPY_AMT      1717 non-null   int64
# ...

# %% [markdown]
# - 카드<P>
# => A_ID + P_CD_OPN + P_CD_USG

# %%
A_ID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5051 entries, 0 to 5050
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   JOIN_SN      5051 non-null   int64
#  1   JOIN_SN_TYP  5051 non-null   int64
#  2   BTH_YR       5051 non-null   int64
#  3   GENDER       5051 non-null   int64
#  4   IS_KRN       5051 non-null   int64
# dtypes: int64(5)
# memory usage: 197.4 KB

# %%
P_CD_OPN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135229 entries, 0 to 135228
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   YM           135229 non-null  int64
#  1   JOIN_SN      135229 non-null  int64
#  2   JOIN_SN_TYP  135229 non-null  int64
#  3   SCTR_CD      135229 non-null  int64
#  4   COM_SN       135229 non-null  int64
#  5   IS_ME        135229 non-null  int64
#  6   CD_OPN_CD_1  135229 non-null  int64
#  7   CD_OPN_CD_2  135229 non-null  int64
#  8   CD_OPN_DT    135229 non-null  int64
# dtypes: int64(9)
# memory usage: 9.3 MB

# %%
P_CD_OPN_cat=pd.merge(A_ID, P_CD_OPN,left_on = ['JOIN_SN','JOIN_SN_TYP'],right_on=['JOIN_SN','JOIN_SN_TYP'],how='inner')
P_CD_OPN_cat
# Out:
#         JOIN_SN  JOIN_SN_TYP  BTH_YR  GENDER  IS_KRN      YM  SCTR_CD  \
# 0        166677            1    1971       1       1  202004        1
# 1        166677            1    1971       1       1  202003        1
# 2        166677            1    1971       1       1  202006        1
# 3        166677            1    1971       1       1  202005        1
# 4        211272            1    1991       2       1  201905        5
# ...         ...          ...     ...     ...     ...     ...      ...
# 135224    47028            1    1975       2       1  202001        5
# 135225    47028            1    1975       2       1  201910        5
# 135226    47028            1    1975       2       1  201808        5
# 135227    47028            1    1975       2       1  202002        5
# 135228    47028            1    1975       2       1  201808        5
#
#          COM_SN  IS_ME  CD_OPN_CD_1  CD_OPN_CD_2  CD_OPN_DT
# 0       1346417      0           81            1     202003
# ...

# %%
P_CD_OPN_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135229 entries, 0 to 135228
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   JOIN_SN      135229 non-null  int64
#  1   JOIN_SN_TYP  135229 non-null  int64
#  2   BTH_YR       135229 non-null  int64
#  3   GENDER       135229 non-null  int64
#  4   IS_KRN       135229 non-null  int64
#  5   YM           135229 non-null  int64
#  6   SCTR_CD      135229 non-null  int64
#  7   COM_SN       135229 non-null  int64
#  8   IS_ME        135229 non-null  int64
#  9   CD_OPN_CD_1  135229 non-null  int64
#  10  CD_OPN_CD_2  135229 non-null  int64
#  11  CD_OPN_DT    135229 non-null  int64
# dtypes: int64(12)
# memory usage: 13.4 MB

# %%
P_CD_USG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108604 entries, 0 to 108603
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   YM           108604 non-null  int64
#  1   JOIN_SN      108604 non-null  int64
#  2   JOIN_SN_TYP  108604 non-null  int64
#  3   SCTR_CD      108604 non-null  int64
#  4   COM_SN       108604 non-null  int64
#  5   IS_ME        108604 non-null  int64
#  6   CD_USG_LMT   108604 non-null  int64
#  7   CD_CA_LMT    108604 non-null  int64
#  8   CD_USG_AMT   108604 non-null  int64
#  9   CD_CA_AMT    108604 non-null  int64
# dtypes: int64(10)
# memory usage: 8.3 MB

# %%
P_CD_OPN_USG_cat=pd.merge(P_CD_USG, P_CD_OPN_cat,left_on = ['JOIN_SN','JOIN_SN_TYP','YM', 'SCTR_CD', 'COM_SN', 'IS_ME'],right_on=['JOIN_SN','JOIN_SN_TYP','YM', 'SCTR_CD', 'COM_SN', 'IS_ME'],how='left')
P_CD_OPN_USG_cat
# Out:
#             YM  JOIN_SN  JOIN_SN_TYP  SCTR_CD   COM_SN  IS_ME  CD_USG_LMT  \
# 0       202001   299165            1        5   847762      0       16000
# 1       202001  1912903            1        5  7727821      0       30000
# 2       201807   689457            1        5  5531601      0       30000
# 3       201911  1920419            1        5  8806279      0       30000
# 4       201810  1113249            1        5  2602876      0       27000
# ...        ...      ...          ...      ...      ...    ...         ...
# 110994  201909   891867            1        5  8266700      0       30000
# 110995  201806   810399            1        5  2184263      0       13000
# 110996  201807  1904625            1        5    71143      0       27000
# 110997  202003  1929498            1        5  9739723      0       30000
# 110998  201908   321744            1        5  5750016      0        6100
#
#         CD_CA_LMT  CD_USG_AMT  CD_CA_AMT  BTH_YR  GENDER  IS_KRN  CD_OPN_CD_1  \
# ...

# %%
P_CD_OPN_USG_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110999 entries, 0 to 110998
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   YM           110999 non-null  int64
#  1   JOIN_SN      110999 non-null  int64
#  2   JOIN_SN_TYP  110999 non-null  int64
#  3   SCTR_CD      110999 non-null  int64
#  4   COM_SN       110999 non-null  int64
#  5   IS_ME        110999 non-null  int64
#  6   CD_USG_LMT   110999 non-null  int64
#  7   CD_CA_LMT    110999 non-null  int64
#  8   CD_USG_AMT   110999 non-null  int64
#  9   CD_CA_AMT    110999 non-null  int64
#  10  BTH_YR       106388 non-null  float64
#  11  GENDER       106388 non-null  float64
#  12  IS_KRN       106388 non-null  float64
#  13  CD_OPN_CD_1  106388 non-null  float64
#  14  CD_OPN_CD_2  106388 non-null  float64
#  15  CD_OPN_DT    106388 non-null  float64
# dtypes: float64(6), int64(10)
# memory usage: 14.4 MB

# %%
P_CD_OPN_USG_cat.isnull().sum()
# Out:
# YM                0
# JOIN_SN           0
# JOIN_SN_TYP       0
# SCTR_CD           0
# COM_SN            0
# IS_ME             0
# CD_USG_LMT        0
# CD_CA_LMT         0
# CD_USG_AMT        0
# CD_CA_AMT         0
# BTH_YR         4611
# GENDER         4611
# IS_KRN         4611
# CD_OPN_CD_1    4611
# CD_OPN_CD_2    4611
# CD_OPN_DT      4611
# dtype: int64

# %%
P_CD_OPN_USG_cat2=P_CD_OPN_USG_cat.dropna(axis=0)

# %%
P_CD_OPN_USG_cat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106388 entries, 0 to 110998
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   YM           106388 non-null  int64
#  1   JOIN_SN      106388 non-null  int64
#  2   JOIN_SN_TYP  106388 non-null  int64
#  3   SCTR_CD      106388 non-null  int64
#  4   COM_SN       106388 non-null  int64
#  5   IS_ME        106388 non-null  int64
#  6   CD_USG_LMT   106388 non-null  int64
#  7   CD_CA_LMT    106388 non-null  int64
#  8   CD_USG_AMT   106388 non-null  int64
#  9   CD_CA_AMT    106388 non-null  int64
#  10  BTH_YR       106388 non-null  float64
#  11  GENDER       106388 non-null  float64
#  12  IS_KRN       106388 non-null  float64
#  13  CD_OPN_CD_1  106388 non-null  float64
#  14  CD_OPN_CD_2  106388 non-null  float64
#  15  CD_OPN_DT    106388 non-null  float64
# dtypes: float64(6), int64(10)
# memory usage: 13.8 MB

# %% [markdown]
# - 보험<P>
# => A_ID + CT_RLPS + CT_CONT_PVT

# %%
A_ID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5051 entries, 0 to 5050
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   JOIN_SN      5051 non-null   int64
#  1   JOIN_SN_TYP  5051 non-null   int64
#  2   BTH_YR       5051 non-null   int64
#  3   GENDER       5051 non-null   int64
#  4   IS_KRN       5051 non-null   int64
# dtypes: int64(5)
# memory usage: 197.4 KB

# %%
CT_RLPS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38400 entries, 0 to 38399
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   JOIN_SN         38400 non-null  int64
#  1   JOIN_SN_TYP     38400 non-null  int64
#  2   SCTR_CD         38400 non-null  int64
#  3   COM_SN          38400 non-null  int64
#  4   IS_ME           38400 non-null  int64
#  5   POL_SN          38400 non-null  int64
#  6   CT_RLPS_GBN_CD  38400 non-null  object
#  7   CT_IN_RLTN_CD   38400 non-null  int64
#  8   IS_INDIV        38400 non-null  int64
#  9   GIS_CD          38400 non-null  int64
# dtypes: int64(9), object(1)
# memory usage: 2.9+ MB

# %%
CT_RLPS_cat=pd.merge(A_ID, CT_RLPS,left_on = ['JOIN_SN','JOIN_SN_TYP'],right_on=['JOIN_SN','JOIN_SN_TYP'],how='inner')
CT_RLPS_cat
# Out:
#        JOIN_SN  JOIN_SN_TYP  BTH_YR  GENDER  IS_KRN  SCTR_CD    COM_SN  IS_ME  \
# 0        74501            1    2000       2       1        6   4390942      0
# 1        74501            1    2000       2       1        6   8519032      0
# 2        74501            1    2000       2       1        8   1231756      0
# 3      1883650            1    2009       1       1        6  10023920      0
# 4      1883650            1    2009       1       1        6   1359893      0
# ...        ...          ...     ...     ...     ...      ...       ...    ...
# 38395    47028            1    1975       2       1        8   4244087      0
# 38396    47028            1    1975       2       1        6   8725632      0
# 38397    47028            1    1975       2       1        8   2466402      0
# 38398    47028            1    1975       2       1        8   4244087      0
# 38399  1357397            1    1997       2       1        6   2980792      0
#
# ...

# %%
CT_RLPS_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38400 entries, 0 to 38399
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   JOIN_SN         38400 non-null  int64
#  1   JOIN_SN_TYP     38400 non-null  int64
#  2   BTH_YR          38400 non-null  int64
#  3   GENDER          38400 non-null  int64
#  4   IS_KRN          38400 non-null  int64
#  5   SCTR_CD         38400 non-null  int64
#  6   COM_SN          38400 non-null  int64
#  7   IS_ME           38400 non-null  int64
#  8   POL_SN          38400 non-null  int64
#  9   CT_RLPS_GBN_CD  38400 non-null  object
#  10  CT_IN_RLTN_CD   38400 non-null  int64
#  11  IS_INDIV        38400 non-null  int64
#  12  GIS_CD          38400 non-null  int64
# dtypes: int64(12), object(1)
# memory usage: 4.1+ MB

# %%
CT_CONT_PVT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38441 entries, 0 to 38440
# Data columns (total 42 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SCTR_CD         38441 non-null  int64
#  1   POL_SN          38441 non-null  int64
#  2   IS_GRP_INS      38441 non-null  int64
#  3   INS_GBN_CD      38441 non-null  int64
#  4   INS_CT_STAT_CD  38441 non-null  int64
#  5   CT_CNCLS_DT     38441 non-null  int64
#  6   CT_TRMNT_DT     38441 non-null  int64
#  7   CT_ST_DT        38441 non-null  int64
#  8   CT_END_DT       38441 non-null  int64
#  9   CT_EFCTV_DT     38441 non-null  int64
#  10  CT_RST_DT       38441 non-null  int64
#  11  CT_PY_AMT       38441 non-null  int64
#  12  CT_PY_CYCLE_CD  38441 non-null  int64
#  13  CT_PY_PD        38441 non-null  int64
#  14  IS_CT_DIGNS     38441 non-null  int64
#  15  CT_JDGMT_CD     38441 non-null  int64
#  16  CT_CHNL_CD      38441 non-null  int64
# ...

# %%
CT_CONT_PVT_cat=pd.merge(CT_RLPS_cat, CT_CONT_PVT,left_on = ['POL_SN','SCTR_CD'],right_on=['POL_SN','SCTR_CD'],how='inner')
CT_CONT_PVT_cat
# Out:
#        JOIN_SN  JOIN_SN_TYP  BTH_YR  GENDER  IS_KRN  SCTR_CD    COM_SN  IS_ME  \
# 0        74501            1    2000       2       1        6   4390942      0
# 1        74501            1    2000       2       1        6   8519032      0
# 2        74501            1    2000       2       1        8   1231756      0
# 3        74501            1    2000       2       1        8   1231756      0
# 4      1883650            1    2009       1       1        6  10023920      0
# ...        ...          ...     ...     ...     ...      ...       ...    ...
# 55659    47028            1    1975       2       1        6   8725632      0
# 55660    47028            1    1975       2       1        8   4244087      0
# 55661    47028            1    1975       2       1        8   4244087      0
# 55662  1357397            1    1997       2       1        6   2980792      0
# 55663  1357397            1    1997       2       1        6   2980792      0
#
# ...

# %%
CT_CONT_PVT_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55664 entries, 0 to 55663
# Data columns (total 53 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   JOIN_SN         55664 non-null  int64
#  1   JOIN_SN_TYP     55664 non-null  int64
#  2   BTH_YR          55664 non-null  int64
#  3   GENDER          55664 non-null  int64
#  4   IS_KRN          55664 non-null  int64
#  5   SCTR_CD         55664 non-null  int64
#  6   COM_SN          55664 non-null  int64
#  7   IS_ME           55664 non-null  int64
#  8   POL_SN          55664 non-null  int64
#  9   CT_RLPS_GBN_CD  55664 non-null  object
#  10  CT_IN_RLTN_CD   55664 non-null  int64
#  11  IS_INDIV        55664 non-null  int64
#  12  GIS_CD          55664 non-null  int64
#  13  IS_GRP_INS      55664 non-null  int64
#  14  INS_GBN_CD      55664 non-null  int64
#  15  INS_CT_STAT_CD  55664 non-null  int64
#  16  CT_CNCLS_DT     55664 non-null  int64
# ...

# %%
CT_CONT_PVT_cat.isnull().sum()
# Out:
# JOIN_SN           0
# JOIN_SN_TYP       0
# BTH_YR            0
# GENDER            0
# IS_KRN            0
# SCTR_CD           0
# COM_SN            0
# IS_ME             0
# POL_SN            0
# CT_RLPS_GBN_CD    0
# CT_IN_RLTN_CD     0
# IS_INDIV          0
# GIS_CD            0
# IS_GRP_INS        0
# INS_GBN_CD        0
# INS_CT_STAT_CD    0
# CT_CNCLS_DT       0
# CT_TRMNT_DT       0
# CT_ST_DT          0
# CT_END_DT         0
# CT_EFCTV_DT       0
# CT_RST_DT         0
# CT_PY_AMT         0
# CT_PY_CYCLE_CD    0
# CT_PY_PD          0
# IS_CT_DIGNS       0
# CT_JDGMT_CD       0
# CT_CHNL_CD        0
# YM_201806         0
# YM_201807         0
# YM_201808         0
# YM_201809         0
# YM_201810         0
# YM_201811         0
# YM_201812         0
# YM_201901         0
# YM_201902         0
# YM_201903         0
# YM_201904         0
# YM_201905         0
# YM_201906         0
# YM_201907         0
# YM_201908         0
# YM_201909         0
# YM_201910         0
# ...

# %% [markdown]
# # 데이터 출력
# - P_LN_cat : 대출(금융)
# - P_LN_SP_cat : 대출(대부)
# - P_CD_OPN_USG_cat2 : 카드
# - CT_CONT_PVT_cat : 보험

# %%
P_LN_cat.to_csv('C:/Users/dlsrn/Desktop/핀테크 인턴쉽/데이터전처리_2/대출(금융).csv', index=False)
P_LN_SP_cat .to_csv('C:/Users/dlsrn/Desktop/핀테크 인턴쉽/데이터전처리_2/대출(대부).csv', index=False)
P_CD_OPN_USG_cat2.to_csv('C:/Users/dlsrn/Desktop/핀테크 인턴쉽/데이터전처리_2/카드.csv', index=False)
CT_CONT_PVT_cat.to_csv('C:/Users/dlsrn/Desktop/핀테크 인턴쉽/데이터전처리_2/보험.csv', index=False)
